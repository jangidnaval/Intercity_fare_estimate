# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('intracity_fare_train.csv')
fd=pd.DataFrame(data=data)

# %%
fd.head()
# Out:
#    ID            TIMESTAMP  STARTING_LATITUDE  STARTING_LONGITUDE  \
# 0   1  2016-01-21 06:59:49          13.044677           80.235723
# 1   2  2016-06-17 22:23:30          28.639580           77.074113
# 2   3  2016-03-16 04:55:18          25.373881           82.969570
# 3   4  2016-04-26 18:10:09                NaN                 NaN
# 4   5  2016-06-22 01:51:35          22.543506           88.446273
#
#    DESTINATION_LATITUDE  DESTINATION_LONGITUDE VEHICLE_TYPE  \
# 0             13.178228              80.163277          Bus
# 1             28.587288              76.971306      Taxi AC
# 2             25.349656              82.992587  Taxi Non AC
# 3             28.758384              77.011422        Metro
# 4             22.706696              88.429522          bus
#
#    TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  TRAFFIC_STUCK_TIME  DISTANCE     FARE
# 0                   NaN        NaN                   8        34    32.09
# 1                   7.0        9.0                  66        34   985.99
# 2                  18.0        6.0                  53         1  1085.33
# 3                   NaN        NaN                  54        31    56.21
# 4                   NaN        NaN                  33        44    30.62

# %%
fd.describe()
# Out:
#                  ID  STARTING_LATITUDE  STARTING_LONGITUDE  \
# count  20000.000000       19325.000000        19325.000000
# mean   10000.500000          20.111445           79.794135
# std     5773.647028           5.908449            4.939736
# min        1.000000          12.842900           72.835882
# 25%     5000.750000          13.086064           77.093570
# 50%    10000.500000          19.231625           77.705107
# 75%    15000.250000          25.317237           82.990730
# max    20000.000000          28.770716           88.452179
#
#        DESTINATION_LATITUDE  DESTINATION_LONGITUDE  TOTAL_LUGGAGE_WEIGHT  \
# count          19337.000000           19337.000000           5648.000000
# mean              20.129680              79.793273             15.447238
# std                5.909585               4.941561              8.558223
# min               12.843029              72.835873              1.000000
# 25%               13.087377              77.087018              8.000000
# 50%               19.235435              77.706558             15.000000
# 75%               25.317921              82.990571             23.000000
# max               28.770713              88.452149             30.000000
#
#          WAIT_TIME  TRAFFIC_STUCK_TIME      DISTANCE          FARE
# count  5648.000000        20000.000000  20000.000000  20000.000000
# mean      9.433605           30.066750     30.543050    251.926063
# std       5.779630           21.951902     12.123407    300.067490
# min       0.000000            0.000000      0.000000      7.000000
# 25%       4.000000           12.000000     22.000000     42.097500
# 50%       9.000000           26.000000     31.000000     75.330000
# 75%      14.000000           45.000000     40.000000    416.130000
# max      19.000000           95.000000     99.000000   1972.000000

# %%
fd.dtypes
# Out:
# ID                         int64
# TIMESTAMP                 object
# STARTING_LATITUDE        float64
# STARTING_LONGITUDE       float64
# DESTINATION_LATITUDE     float64
# DESTINATION_LONGITUDE    float64
# VEHICLE_TYPE              object
# TOTAL_LUGGAGE_WEIGHT     float64
# WAIT_TIME                float64
# TRAFFIC_STUCK_TIME         int64
# DISTANCE                   int64
# FARE                     float64
# dtype: object

# %%
fd[['STARTING_LATITUDE','STARTING_LONGITUDE','DESTINATION_LATITUDE','DESTINATION_LONGITUDE','TOTAL_LUGGAGE_WEIGHT','WAIT_TIME','TRAFFIC_STUCK_TIME','FARE']]=fd[['STARTING_LATITUDE','STARTING_LONGITUDE','DESTINATION_LATITUDE','DESTINATION_LONGITUDE','TOTAL_LUGGAGE_WEIGHT','WAIT_TIME','TRAFFIC_STUCK_TIME','FARE']].apply(pd.to_numeric)

# %%
fd.dtypes
# Out:
# ID                         int64
# TIMESTAMP                 object
# STARTING_LATITUDE        float64
# STARTING_LONGITUDE       float64
# DESTINATION_LATITUDE     float64
# DESTINATION_LONGITUDE    float64
# VEHICLE_TYPE              object
# TOTAL_LUGGAGE_WEIGHT     float64
# WAIT_TIME                float64
# TRAFFIC_STUCK_TIME         int64
# DISTANCE                   int64
# FARE                     float64
# dtype: object

# %%
str=fd['TIMESTAMP'][0]

# %%
import datetime

# %%
datetime.datetime.today().year
x=datetime.datetime(2016,5,27,18,10,9).weekday()
y=datetime.datetime(2016,5,27).weekday()
x
y
# Out:
# 4

# %%
datetime.datetime(2016,4,27,18,10,9).weekday()
# Out:
# 2

# %%
def fun_time(row):
    str=row['TIMESTAMP']
    hr=int(str[11:13])
    mi=int(str[14:16])
    
    if mi in range(15,45):
        hr=hr+.5
    else:
        if mi>=45:
            hr=(hr+1)%24
    
    return hr
  

def fun_day(row):
    str=row['TIMESTAMP']
    
    #str=fd['TIMESTAMP'][5]
    yr=int(str[:4])
    # print(yr)
    mn=int(str[5:7])
    dy=int(str[8:10])
      #week start from monday   monday=0
        #tues=1 wed =2.... sat=5 sun=6
    x=datetime.datetime(yr,mn,dy).weekday()
    #print(str)
    #print(mn)
    #print(dy)
    return x

# %%
fd['TIME']=fd.apply(lambda row:fun_time(row),axis=1)
fd['DAY']=fd.apply(lambda row:fun_day(row),axis=1)


fd.drop('TIMESTAMP',axis=1,inplace=True)

# %%
fd.drop('ID',axis=1,inplace=True)

# %%
 #week start from monday   monday=0
        #tues=1 wed =2.... sat=5 sun=6
fd.head()
# Out:
#    STARTING_LATITUDE  STARTING_LONGITUDE  DESTINATION_LATITUDE  \
# 0          13.044677           80.235723             13.178228
# 1          28.639580           77.074113             28.587288
# 2          25.373881           82.969570             25.349656
# 3                NaN                 NaN             28.758384
# 4          22.543506           88.446273             22.706696
#
#    DESTINATION_LONGITUDE VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  \
# 0              80.163277          Bus                   NaN        NaN
# 1              76.971306      Taxi AC                   7.0        9.0
# 2              82.992587  Taxi Non AC                  18.0        6.0
# 3              77.011422        Metro                   NaN        NaN
# 4              88.429522          bus                   NaN        NaN
#
#    TRAFFIC_STUCK_TIME  DISTANCE     FARE  TIME  DAY
# 0                   8        34    32.09   7.0    3
# 1                  66        34   985.99  22.5    4
# 2                  53         1  1085.33   5.0    2
# 3                  54        31    56.21  18.0    1
# 4                  33        44    30.62   2.0    2

# %%
fd['STARTING_LATITUDE'].mean()

fd['STARTING_LATITUDE'].fillna(value=fd['STARTING_LATITUDE'].mean(),inplace=True)

fd['STARTING_LONGITUDE'].fillna(value=fd['STARTING_LONGITUDE'].mean(),inplace=True)

fd['DESTINATION_LATITUDE'].fillna(value=fd['DESTINATION_LATITUDE'].mean(),inplace=True)

fd['DESTINATION_LONGITUDE'].fillna(value=fd['DESTINATION_LONGITUDE'].mean(),inplace=True)

# %%
#Fetch City
chukk = []
for i in range(20000):
    if ( (int(fd['STARTING_LATITUDE'][i])) == 28 or (int(fd['DESTINATION_LATITUDE'][i])) == 28 or (int(fd['STARTING_LONGITUDE'][i])) == 76 or (int(fd['DESTINATION_LONGITUDE'][i])) == 76 or ( (int(fd['STARTING_LATITUDE'][i])) == 28 and (int(fd['STARTING_LONGITUDE'][i])) == 77 ) or ( (int(fd['STARTING_LATITUDE'][i])) == 28 and (int(fd['STARTING_LONGITUDE'][i])) == 76 ) or ( (int(fd['DESTINATION_LATITUDE'][i])) == 28 and (int(fd['DESTINATION_LONGITUDE'][i])) == 77 ) or ((int(fd['DESTINATION_LATITUDE'][i])) == 28 and (int(fd['DESTINATION_LONGITUDE'][i])) == 76) ):
        chukk.append(1)
    elif (int(fd['STARTING_LATITUDE'][i])) == 25 or (int(fd['DESTINATION_LATITUDE'][i])) == 25 or (int(fd['STARTING_LONGITUDE'][i])) == 82 or (int(fd['STARTING_LONGITUDE'][i])) == 83 or (int(fd['DESTINATION_LONGITUDE'][i])) == 82 or (int(fd['DESTINATION_LONGITUDE'][i])) == 83:
        chukk.append(2)
    elif (int(fd['STARTING_LATITUDE'][i])) == 22 or (int(fd['DESTINATION_LATITUDE'][i])) == 22 or (int(fd['STARTING_LONGITUDE'][i])) == 88 or (int(fd['DESTINATION_LONGITUDE'][i])) == 88:
        chukk.append(3)
    elif (int(fd['STARTING_LATITUDE'][i])) == 19 or (int(fd['DESTINATION_LATITUDE'][i])) == 19 or (int(fd['STARTING_LONGITUDE'][i])) == 72 or (int(fd['DESTINATION_LONGITUDE'][i])) == 72:
        chukk.append(4)
    elif (int(fd['STARTING_LONGITUDE'][i])) == 80 or (int(fd['DESTINATION_LONGITUDE'][i])) == 80 or ( (int(fd['STARTING_LATITUDE'][i])) == 12 and (int(fd['STARTING_LONGITUDE'][i])) == 80 ) or ( (int(fd['STARTING_LATITUDE'][i])) == 13 and (int(fd['STARTING_LONGITUDE'][i])) == 80 ) or ( (int(fd['DESTINATION_LATITUDE'][i])) == 12 and (int(fd['DESTINATION_LONGITUDE'][i])) == 80 ) or ( (int(fd['DESTINATION_LATITUDE'][i])) == 13 and (int(fd['DESTINATION_LONGITUDE'][i])) == 80 ):
        chukk.append(5)
    elif (int(fd['STARTING_LONGITUDE'][i])) == 77 or (int(fd['DESTINATION_LONGITUDE'][i])) == 77 or ( (int(fd['STARTING_LATITUDE'][i])) == 12 and (int(fd['STARTING_LONGITUDE'][i])) == 77 ) or ( (int(fd['STARTING_LATITUDE'][i])) == 13 and (int(fd['STARTING_LONGITUDE'][i])) == 77 ) or ( (int(fd['DESTINATION_LATITUDE'][i])) == 12 and (int(fd['DESTINATION_LONGITUDE'][i])) == 77 ) or ( (int(fd['DESTINATION_LATITUDE'][i])) == 13 and (int(fd['DESTINATION_LONGITUDE'][i])) == 77 ):
        chukk.append(6)
    else:
        chukk.append(0)

fd['CITY']=chukk

# %%
fd.head()
# Out:
#    STARTING_LATITUDE  STARTING_LONGITUDE  DESTINATION_LATITUDE  \
# 0          13.044677           80.235723             13.178228
# 1          28.639580           77.074113             28.587288
# 2          25.373881           82.969570             25.349656
# 3          20.111445           79.794135             28.758384
# 4          22.543506           88.446273             22.706696
#
#    DESTINATION_LONGITUDE VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  \
# 0              80.163277          Bus                   NaN        NaN
# 1              76.971306      Taxi AC                   7.0        9.0
# 2              82.992587  Taxi Non AC                  18.0        6.0
# 3              77.011422        Metro                   NaN        NaN
# 4              88.429522          bus                   NaN        NaN
#
#    TRAFFIC_STUCK_TIME  DISTANCE     FARE  TIME  DAY  CITY
# 0                   8        34    32.09   7.0    3     5
# 1                  66        34   985.99  22.5    4     1
# 2                  53         1  1085.33   5.0    2     2
# 3                  54        31    56.21  18.0    1     1
# 4                  33        44    30.62   2.0    2     3

# %%
fd.drop('STARTING_LATITUDE',axis=1,inplace=True)
fd.drop('STARTING_LONGITUDE',axis=1,inplace=True)
fd.drop('DESTINATION_LATITUDE',axis=1,inplace=True)
fd.drop('DESTINATION_LONGITUDE',axis=1,inplace=True)

# %%
f1=fd
con=f1['TOTAL_LUGGAGE_WEIGHT']>0

f1=f1[con]

f1.head()
# Out:
#    VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  TRAFFIC_STUCK_TIME  \
# 1       Taxi AC                   7.0        9.0                  66
# 2   Taxi Non AC                  18.0        6.0                  53
# 6   taxi Non ac                  22.0        0.0                  61
# 8       Taxi AC                  12.0       18.0                  69
# 10      Taxi AC                  17.0       19.0                  39
#
#     DISTANCE     FARE  TIME  DAY  CITY
# 1         34   985.99  22.5    4     1
# 2          1  1085.33   5.0    2     2
# 6         34   586.36  16.5    2     4
# 8         43  1122.08  14.5    0     2
# 10        41   901.34   5.5    4     4

# %%
arr=fd.columns

# %%
arr[6]
# Out:
# 'TIME'

# %%
fd[fd['VEHICLE_TYPE']>0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-376-6a56f06dfb8b> in <module>()
# ----> 1 fd[fd['VEHICLE_TYPE']>0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     763
#     764         if is_object_dtype(x.dtype):
# --> 765             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     766         else:
#     767
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#     743         result = lib.vec_compare(x, y, op)
#     744     else:
# --> 745         result = lib.scalar_compare(x, y, op)
#     746     return result
#     747
#
# pandas\_libs\lib.pyx in pandas._libs.lib.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
t_table=fd>0

# %%
t_table.describe()
# Out:
#        VEHICLE_TYPE TOTAL_LUGGAGE_WEIGHT WAIT_TIME TRAFFIC_STUCK_TIME  \
# count         20000                20000     20000              20000
# unique            1                    2         2                  2
# top            True                False     False               True
# freq          20000                14352     14650              19623
#
#        DISTANCE   FARE   TIME    DAY   CITY
# count     20000  20000  20000  20000  20000
# unique        2      1      2      2      2
# top        True   True   True   True   True
# freq      19954  20000  19599  17230  19662

# %%
fd.head()
# Out:
#   VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  TRAFFIC_STUCK_TIME  DISTANCE  \
# 0          Bus                   NaN        NaN                   8        34
# 1      Taxi AC                   7.0        9.0                  66        34
# 2  Taxi Non AC                  18.0        6.0                  53         1
# 3        Metro                   NaN        NaN                  54        31
# 4          bus                   NaN        NaN                  33        44
#
#       FARE  TIME  DAY  CITY
# 0    32.09   7.0    3     5
# 1   985.99  22.5    4     1
# 2  1085.33   5.0    2     2
# 3    56.21  18.0    1     1
# 4    30.62   2.0    2     3

# %%
fd.describe()
# Out:
#        TOTAL_LUGGAGE_WEIGHT    WAIT_TIME  TRAFFIC_STUCK_TIME      DISTANCE  \
# count           5648.000000  5648.000000        20000.000000  20000.000000
# mean              15.447238     9.433605           30.066750     30.543050
# std                8.558223     5.779630           21.951902     12.123407
# min                1.000000     0.000000            0.000000      0.000000
# 25%                8.000000     4.000000           12.000000     22.000000
# 50%               15.000000     9.000000           26.000000     31.000000
# 75%               23.000000    14.000000           45.000000     40.000000
# max               30.000000    19.000000           95.000000     99.000000
#
#                FARE          TIME           DAY          CITY
# count  20000.000000  20000.000000  20000.000000  20000.000000
# mean     251.926063     11.717600      3.027000      3.486200
# std      300.067490      6.894264      1.998817      1.755723
# min        7.000000      0.000000      0.000000      0.000000
# 25%       42.097500      5.500000      1.000000      2.000000
# 50%       75.330000     11.500000      3.000000      4.000000
# 75%      416.130000     17.500000      5.000000      5.000000
# max     1972.000000     23.500000      6.000000      6.000000

# %%
#f1=f1.reset_index(drop=True)

# %%
#f1.index.size

# %%
#f1['VEHICLE_TYPE'][2]

# %%
#f1['VEHICLE_TYPE'][0]='ok'
#f1['VEHICLE_TYPE'][0]='bus'

# %%
#f1.set_value(0,'VEHICLE_TYPE','okok')
#f1.index.size

# %%
#trying to make all upper case in vehicle type  
#for i in range(0,f1.index.size):
 #   f1.set_value(i,'VEHICLE_TYPE',)
#but there is 
fd['VEHICLE_TYPE']=fd['VEHICLE_TYPE'].str.upper()

# %%
fd['VEHICLE_TYPE'].unique()
# Out:
# array(['BUS', 'TAXI AC', 'TAXI NON AC', 'METRO', 'AC BUS', 'MINI BUS',
#        'AUTO RICKSHAW'], dtype=object)

# %%
a4_dims = (18,7)

fig, ax = plt.subplots(figsize=a4_dims)

sns.barplot(x='VEHICLE_TYPE',y='FARE',data=fd,ax=ax)

# %%
f2=fd[['VEHICLE_TYPE','FARE']]
# In[391]:
f3=f2.groupby('VEHICLE_TYPE')
# In[392]:
f3.count()
# In[393]:
f3.mean()
# Out:
#                      FARE
# VEHICLE_TYPE
# AC BUS          76.374572
# AUTO RICKSHAW  441.549829
# BUS             58.495373
# METRO           51.184810
# MINI BUS        69.066456
# TAXI AC        588.609643
# TAXI NON AC    496.990639

# %%
x=f1.corr()

# %%
fig, ax = plt.subplots(figsize=(18,7))

sns.heatmap(x,annot=True,ax=ax)

# %%
a4_dims = (18,7)

fig, ax = plt.subplots(figsize=a4_dims)

sns.boxplot(x='VEHICLE_TYPE',y='FARE',data=f2,width=.8, ax=ax)

# %%
f4=f3.count()

# %%
f4.sort_values('FARE')
# Out:
#                FARE
# VEHICLE_TYPE
# METRO          2786
# TAXI AC        2798
# AUTO RICKSHAW  2799
# TAXI NON AC    2850
# BUS            2885
# MINI BUS       2918
# AC BUS         2964

# %%
f1.head()
# Out:
#    VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  TRAFFIC_STUCK_TIME  \
# 1       Taxi AC                   7.0        9.0                  66
# 2   Taxi Non AC                  18.0        6.0                  53
# 6   taxi Non ac                  22.0        0.0                  61
# 8       Taxi AC                  12.0       18.0                  69
# 10      Taxi AC                  17.0       19.0                  39
#
#     DISTANCE     FARE  TIME  DAY  CITY
# 1         34   985.99  22.5    4     1
# 2          1  1085.33   5.0    2     2
# 6         34   586.36  16.5    2     4
# 8         43  1122.08  14.5    0     2
# 10        41   901.34   5.5    4     4

# %%
pip install geopy
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install geopy
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
from math import sin, cos, sqrt, atan2, radians

# %%
from geopy.distance import vincenty

# %%
#R = 6373.0  radius of earth
#dlon = lon2 - lon1
#dlat = lat2 - lat1

#a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
#c = 2 * atan2(sqrt(a), sqrt(1 - a))

#distance = R * c



# Define the two points
#start = (start_latitute, start_longitude)
#stop = (stop_latitude, stop_longitude)

# Print the vincenty distance
#print(vincenty(start, stop).meters)

# Print the great circle distance
#print(great_circle(start, stop).meters)

# %%
def distance_calc (row):
    start = (row['STARTING_LATITUDE'], row['STARTING_LONGITUDE'])
    stop = (row['DESTINATION_LATITUDE'], row['DESTINATION_LONGITUDE'])

    return (vincenty(start, stop).meters)/1000

#fd['DIR_DISTANCE'] = fd.apply (lambda row: distance_calc (row),axis=1)

# %%
#fd.drop('DIR_DISTANCE',axis=1)

# %%
fd['VEHICLE_TYPE'].fillna('NOT_GIVEN')
# Out:
# 0                  BUS
# 1              TAXI AC
# 2          TAXI NON AC
# 3                METRO
# 4                  BUS
# 5               AC BUS
# 6          TAXI NON AC
# 7                  BUS
# 8              TAXI AC
# 9                METRO
# 10             TAXI AC
# 11                 BUS
# 12            MINI BUS
# 13               METRO
# 14                 BUS
# 15               METRO
# 16            MINI BUS
# 17               METRO
# 18       AUTO RICKSHAW
# 19         TAXI NON AC
# 20              AC BUS
# 21               METRO
# 22         TAXI NON AC
# 23              AC BUS
# 24       AUTO RICKSHAW
# 25               METRO
# 26              AC BUS
# 27            MINI BUS
# 28       AUTO RICKSHAW
# 29                 BUS
#              ...
# 19970         MINI BUS
# 19971           AC BUS
# 19972            METRO
# 19973          TAXI AC
# 19974         MINI BUS
# 19975            METRO
# 19976          TAXI AC
# 19977    AUTO RICKSHAW
# 19978            METRO
# 19979           AC BUS
# 19980            METRO
# 19981          TAXI AC
# 19982         MINI BUS
# 19983      TAXI NON AC
# 19984      TAXI NON AC
# 19985            METRO
# 19986          TAXI AC
# 19987          TAXI AC
# 19988      TAXI NON AC
# 19989           AC BUS
# 19990         MINI BUS
# 19991         MINI BUS
# 19992          TAXI AC
# 19993         MINI BUS
# 19994            METRO
# 19995          TAXI AC
# 19996          TAXI AC
# 19997          TAXI AC
# 19998              BUS
# 19999           AC BUS
# Name: VEHICLE_TYPE, Length: 20000, dtype: object

# %%
fd.count()
# Out:
# VEHICLE_TYPE            20000
# TOTAL_LUGGAGE_WEIGHT     5648
# WAIT_TIME                5648
# TRAFFIC_STUCK_TIME      20000
# DISTANCE                20000
# FARE                    20000
# TIME                    20000
# DAY                     20000
# CITY                    20000
# dtype: int64

# %%
#plt.scatter(x='DIR_DISTANCE',y='FARE',data=fd, hue='VEHICLE_TYPE')

# %%
sns.distplot(fd['FARE'])

# %%
fig, ax = plt.subplots(figsize=(18,7))
sns.boxplot(x='TIME',y='FARE',data=fd,ax=ax,)

# %%
 # f_vip is  fd of auto and taxi
f_vip=pd.DataFrame(columns=fd.columns)
f_ord=pd.DataFrame(columns=fd.columns)

# %%
for i in range(0,fd.index.size):
    if fd['VEHICLE_TYPE'][i] in ('AUTO RICKSHAW','TAXI AC','TAXI NON AC'):
        f_vip=f_vip.append(fd.iloc[[i]])
    else:
        f_ord=f_ord.append(fd.iloc[[i]])

# %%
f_vip.head()
# Out:
#    VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME TRAFFIC_STUCK_TIME DISTANCE  \
# 1       TAXI AC                   7.0        9.0                 66       34
# 2   TAXI NON AC                  18.0        6.0                 53        1
# 6   TAXI NON AC                  22.0        0.0                 61       34
# 8       TAXI AC                  12.0       18.0                 69       43
# 10      TAXI AC                  17.0       19.0                 39       41
#
#        FARE  TIME DAY CITY
# 1    985.99  22.5   4    1
# 2   1085.33   5.0   2    2
# 6    586.36  16.5   2    4
# 8   1122.08  14.5   0    2
# 10   901.34   5.5   4    4

# %%
f_ord.head()
# Out:
#   VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME TRAFFIC_STUCK_TIME DISTANCE  \
# 0          BUS                   NaN        NaN                  8       34
# 3        METRO                   NaN        NaN                 54       31
# 4          BUS                   NaN        NaN                 33       44
# 5       AC BUS                   NaN        NaN                 23       43
# 7          BUS                   NaN        NaN                 28       18
#
#     FARE  TIME DAY CITY
# 0  32.09   7.0   3    5
# 3  56.21  18.0   1    1
# 4  30.62   2.0   2    3
# 5  59.82  16.0   4    4
# 7  32.27   9.0   3    6

# %%
f_vip.reset_index(inplace=True,drop=True)
f_ord.reset_index(inplace=True,drop=True)

# %%
f_vip.head()
# Out:
#   VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME TRAFFIC_STUCK_TIME DISTANCE  \
# 0      TAXI AC                   7.0        9.0                 66       34
# 1  TAXI NON AC                  18.0        6.0                 53        1
# 2  TAXI NON AC                  22.0        0.0                 61       34
# 3      TAXI AC                  12.0       18.0                 69       43
# 4      TAXI AC                  17.0       19.0                 39       41
#
#       FARE  TIME DAY CITY
# 0   985.99  22.5   4    1
# 1  1085.33   5.0   2    2
# 2   586.36  16.5   2    4
# 3  1122.08  14.5   0    2
# 4   901.34   5.5   4    4

# %%
f_ord.drop('WAIT_TIME',axis=1,inplace=True)
f_ord.drop('TOTAL_LUGGAGE_WEIGHT',axis=1,inplace=True)

# %%
f_ord.head()
# Out:
#   VEHICLE_TYPE TRAFFIC_STUCK_TIME DISTANCE   FARE  TIME DAY CITY
# 0          BUS                  8       34  32.09   7.0   3    5
# 1        METRO                 54       31  56.21  18.0   1    1
# 2          BUS                 33       44  30.62   2.0   2    3
# 3       AC BUS                 23       43  59.82  16.0   4    4
# 4          BUS                 28       18  32.27   9.0   3    6

# %%
f_ord.count()
# Out:
# VEHICLE_TYPE          11553
# TRAFFIC_STUCK_TIME    11553
# DISTANCE              11553
# FARE                  11553
# TIME                  11553
# DAY                   11553
# CITY                  11553
# dtype: int64

# %%
f_vip.count()
# Out:
# VEHICLE_TYPE            8447
# TOTAL_LUGGAGE_WEIGHT    5648
# WAIT_TIME               5648
# TRAFFIC_STUCK_TIME      8447
# DISTANCE                8447
# FARE                    8447
# TIME                    8447
# DAY                     8447
# CITY                    8447
# dtype: int64

# %%
f_vip.dtypes
# Out:
# VEHICLE_TYPE             object
# TOTAL_LUGGAGE_WEIGHT    float64
# WAIT_TIME               float64
# TRAFFIC_STUCK_TIME        int64
# DISTANCE                  int64
# FARE                    float64
# TIME                    float64
# DAY                       int64
# CITY                      int64
# dtype: object

# %%
f_ord.dtypes
# Out:
# VEHICLE_TYPE           object
# TRAFFIC_STUCK_TIME     object
# DISTANCE                int64
# FARE                  float64
# TIME                  float64
# DAY                     int64
# CITY                    int64
# dtype: object

# %%
f_vip[['TRAFFIC_STUCK_TIME','DISTANCE','DAY','CITY']]=f_vip[['TRAFFIC_STUCK_TIME','DISTANCE','DAY','CITY']].apply(pd.to_numeric)
f_ord[['TRAFFIC_STUCK_TIME','DISTANCE','DAY','CITY']]=f_ord[['TRAFFIC_STUCK_TIME','DISTANCE','DAY','CITY']].apply(pd.to_numeric)

# %%
f_ord.describe()
# Out:
#        TRAFFIC_STUCK_TIME      DISTANCE          FARE          TIME  \
# count        11553.000000  11553.000000  11553.000000  11553.000000
# mean            29.905652     30.553017     63.989456     11.766208
# std             21.908221     12.105370    133.043721      6.881912
# min              0.000000      0.000000      7.000000      0.000000
# 25%             12.000000     22.000000     34.350000      6.000000
# 50%             26.000000     31.000000     45.690000     12.000000
# 75%             44.000000     40.000000     64.070000     17.500000
# max             95.000000     99.000000   1972.000000     23.500000
#
#                 DAY          CITY
# count  11553.000000  11553.000000
# mean       3.016273      3.519432
# std        1.992605      1.756958
# min        0.000000      0.000000
# 25%        1.000000      2.000000
# 50%        3.000000      4.000000
# 75%        5.000000      5.000000
# max        6.000000      6.000000

# %%
f_ord.head()
# Out:
#   VEHICLE_TYPE  TRAFFIC_STUCK_TIME  DISTANCE   FARE  TIME  DAY  CITY
# 0          BUS                   8        34  32.09   7.0    3     5
# 1        METRO                  54        31  56.21  18.0    1     1
# 2          BUS                  33        44  30.62   2.0    2     3
# 3       AC BUS                  23        43  59.82  16.0    4     4
# 4          BUS                  28        18  32.27   9.0    3     6

# %%
f_vip.head()
# Out:
#   VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  TRAFFIC_STUCK_TIME  DISTANCE  \
# 0      TAXI AC                   7.0        9.0                  66        34
# 1  TAXI NON AC                  18.0        6.0                  53         1
# 2  TAXI NON AC                  22.0        0.0                  61        34
# 3      TAXI AC                  12.0       18.0                  69        43
# 4      TAXI AC                  17.0       19.0                  39        41
#
#       FARE  TIME  DAY  CITY
# 0   985.99  22.5    4     1
# 1  1085.33   5.0    2     2
# 2   586.36  16.5    2     4
# 3  1122.08  14.5    0     2
# 4   901.34   5.5    4     4

# %%
#'O'     (Python) objects
f_ord=f_ord.convert_objects(convert_numeric=True)
f_vip=f_vip.convert_objects(convert_numeric=True)
#f_ord['TRAFFIC_STUCK_TIME']=f_ord['TRAFFIC_STUCK_TIME'].convert_objects(convert_numeric=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
f_ord['DISTANCE'].dtype
f_ord['TRAFFIC_STUCK_TIME'].dtype
# Out:
# dtype('int64')

# %%
sns.pairplot(f_ord)

# %%
#fig, ax = plt.subplots(figsize=(18,7))
#sns.boxplot(x='VEHICLE_TYPE',y='FARE',data=f_ord,hue='DAY',ax=ax,)

# %%
f_ord.head()
# Out:
#   VEHICLE_TYPE  TRAFFIC_STUCK_TIME  DISTANCE   FARE  TIME  DAY  CITY
# 0          BUS                   8        34  32.09   7.0    3     5
# 1        METRO                  54        31  56.21  18.0    1     1
# 2          BUS                  33        44  30.62   2.0    2     3
# 3       AC BUS                  23        43  59.82  16.0    4     4
# 4          BUS                  28        18  32.27   9.0    3     6

# %%
f1=f_ord.sort_values(by=['DISTANCE'],ascending=False)
#f1=f_ord.sort_values(by=['FARE'],ascending=False)
f1.head(n=50)
# Out:
#       VEHICLE_TYPE  TRAFFIC_STUCK_TIME  DISTANCE   FARE  TIME  DAY  CITY
# 10285     MINI BUS                   8        99  39.70   5.0    0     6
# 1082      MINI BUS                  65        99  91.05  13.0    1     1
# 4745         METRO                  15        98  20.00  20.5    1     3
# 11531     MINI BUS                  17        97  68.33   7.5    1     1
# 5218        AC BUS                   4        97  46.40  13.0    2     5
# 10130     MINI BUS                   0        96  48.36  21.0    1     6
# 679          METRO                  14        96  39.29  13.5    0     3
# 2674        AC BUS                  14        95  80.00  16.0    0     4
# 5620        AC BUS                  26        93  73.16  13.0    3     2
# 10698        METRO                  37        92  31.43  11.0    0     5
# 10544        METRO                   4        92  40.21  18.0    0     3
# 2957        AC BUS                  19        91  43.20  22.5    0     5
# 8761           BUS                   6        91  63.33   3.0    4     2
# 7072           BUS                  89        91  27.38  19.5    2     6
# 3563      MINI BUS                  28        91  62.50  11.5    4     2
# 2532        AC BUS                  17        90  39.46  18.0    4     6
# 8753           BUS                  57        89  23.66  16.0    4     5
# 7244           BUS                  25        89  27.38  23.0    4     6
# 4346      MINI BUS                  31        87  39.18  10.5    5     5
# 8170         METRO                  36        87  27.72   9.0    0     5
# 10783       AC BUS                  60        87  73.16   8.5    3     1
# 1367        AC BUS                  30        87  90.00  13.5    1     2
# 1545      MINI BUS                  62        86  62.50   7.5    4     2
# 741          METRO                  69        86  32.91  14.5    2     5
# 9416      MINI BUS                  72        86  35.22   8.0    4     6
# 2291        AC BUS                  30        85  34.61  12.0    1     5
# 8867        AC BUS                  48        83  56.53  16.5    2     3
# 9427           BUS                   4        82  19.56   6.0    5     4
# 9406      MINI BUS                  13        82  41.89  12.0    5     5
# 10464       AC BUS                  62        80  74.21  15.5    0     1
# 721          METRO                   1        79  35.33   7.0    1     5
# 7864        AC BUS                  13        79  83.33   5.0    0     2
# 4209      MINI BUS                  57        77  63.78   5.5    4     4
# 5054        AC BUS                  22        77  52.00  22.5    3     3
# 11461          BUS                  44        77  51.11  12.0    0     2
# 7209         METRO                  39        76  40.03  18.5    4     4
# 3374           BUS                  48        76  32.55  20.5    0     3
# 6734         METRO                  74        76  34.67   5.0    1     5
# 8993           BUS                  33        75  25.29  22.5    2     5
# 5844        AC BUS                  47        75  58.80   6.5    4     3
# 5594         METRO                  34        75  65.28  18.0    2     1
# 1822      MINI BUS                   6        74  91.05   6.5    0     1
# 4481           BUS                  46        73  54.26  14.5    3     1
# 7577         METRO                  35        73  24.76  21.0    2     5
# 142          METRO                  71        71  54.86   7.5    5     4
# 9792      MINI BUS                  37        71  47.84  16.0    1     3
# 1715           BUS                  19        71  26.63   2.0    6     6
# 4154           BUS                  11        71  60.55  20.0    2     2
# 942          METRO                  37        71  45.40   4.0    2     1
# 7702        AC BUS                  12        71  84.78  13.5    6     2

# %% [raw]
# #long distance buses have more  fare charges and in with a range like 20km fares are too low

# %%
sns.lmplot(y='FARE',x='DISTANCE',data=f_ord,hue='TIME',fit_reg=False)

# %%
sns.distplot(fd['TIME'])

# %%
sns.distplot(fd['FARE'])

# %%
sns.rugplot(fd['FARE'],axis=1)

# %%
sns.rugplot(fd['TIME'],axis=1)

# %%
fd.head()
# Out:
#    ID            TIMESTAMP  STARTING_LATITUDE  STARTING_LONGITUDE  \
# 0   1  2016-01-21 06:59:49          13.044677           80.235723
# 1   2  2016-06-17 22:23:30          28.639580           77.074113
# 2   3  2016-03-16 04:55:18          25.373881           82.969570
# 3   4  2016-04-26 18:10:09          20.111445           79.794135
# 4   5  2016-06-22 01:51:35          22.543506           88.446273
#
#    DESTINATION_LATITUDE  DESTINATION_LONGITUDE VEHICLE_TYPE  \
# 0             13.178228              80.163277          Bus
# 1             28.587288              76.971306      Taxi AC
# 2             25.349656              82.992587  Taxi Non AC
# 3             28.758384              77.011422        Metro
# 4             22.706696              88.429522          bus
#
#    TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  TRAFFIC_STUCK_TIME  DISTANCE     FARE  \
# 0                   NaN        NaN                   8        34    32.09
# 1                   7.0        9.0                  66        34   985.99
# 2                  18.0        6.0                  53         1  1085.33
# 3                   NaN        NaN                  54        31    56.21
# 4                   NaN        NaN                  33        44    30.62
#
#    TIME  DAY  CITY
# 0   7.0    3     5
# 1  22.5    4     1
# 2   5.0    2     2
# 3  18.0    1     1
# 4   2.0    2     3

# %%
arr=np.array(fd[['STARTING_LATITUDE','STARTING_LONGITUDE','DESTINATION_LATITUDE','DESTINATION_LONGITUDE']])

# %%
arr
# Out:
# array([[ 13.044677,  80.235723,  13.178228,  80.163277],
#        [ 28.63958 ,  77.074113,  28.587288,  76.971306],
#        [ 25.373881,  82.96957 ,  25.349656,  82.992587],
#        ...,
#        [ 13.012673,  80.209958,  13.053211,  80.206934],
#        [ 13.006869,  77.510779,  12.860101,  77.520207],
#        [ 12.890407,  77.464352,  12.987765,  77.636698]])

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans(n_clusters=6)
km.fit(arr)

plt.scatter(arr[:,0],arr[:,1],c=km.labels_,cmap='rainbow')

# %%
km.labels_
# Out:
# array([2, 3, 4, ..., 2, 2, 2])

# %%
km.cluster_centers_
# Out:
# array([[ 19.13233346,  72.86036408],
#        [ 25.32465818,  82.99334287],
#        [ 13.11572042,  80.19718223],
#        [ 28.65991263,  77.03153315],
#        [ 22.5956685 ,  88.41347646],
#        [ 20.11144455,  79.79413522],
#        [ 13.06511958,  77.58972468],
#        [ 28.66699598,  77.16929747],
#        [ 12.91687204,  77.5901084 ],
#        [ 12.95191092,  80.19661892]])

# %%
km.labels_
# Out:
# array([2, 3, 1, ..., 9, 6, 8])

# %%
plt.scatter(arr[:,0],arr[:,1],c=km.labels_,cmap='rainbow')

# %%
arr[0][:,0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-a8e40f2af29b> in <module>()
# ----> 1 arr[0][:,0]
#
# IndexError: too many indices for array

# %%
arr
# Out:
# array([[ 13.044677,  80.235723],
#        [ 28.63958 ,  77.074113],
#        [ 25.373881,  82.96957 ],
#        ...,
#        [ 13.012673,  80.209958],
#        [ 13.006869,  77.510779],
#        [ 12.890407,  77.464352]])

# %%
arr[:,0]
# Out:
# array([ 13.044677,  28.63958 ,  25.373881, ...,  13.012673,  13.006869,
#         12.890407])

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.9,random_state=101)

# %%
data.head()
# Out:
#    ID            TIMESTAMP  STARTING_LATITUDE  STARTING_LONGITUDE  \
# 0   1  2016-01-21 06:59:49          13.044677           80.235723
# 1   2  2016-06-17 22:23:30          28.639580           77.074113
# 2   3  2016-03-16 04:55:18          25.373881           82.969570
# 3   4  2016-04-26 18:10:09                NaN                 NaN
# 4   5  2016-06-22 01:51:35          22.543506           88.446273
#
#    DESTINATION_LATITUDE  DESTINATION_LONGITUDE VEHICLE_TYPE  \
# 0             13.178228              80.163277          Bus
# 1             28.587288              76.971306      Taxi AC
# 2             25.349656              82.992587  Taxi Non AC
# 3             28.758384              77.011422        Metro
# 4             22.706696              88.429522          bus
#
#    TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  TRAFFIC_STUCK_TIME  DISTANCE     FARE  \
# 0                   NaN        NaN                   8        34    32.09
# 1                   7.0        9.0                  66        34   985.99
# 2                  18.0        6.0                  53         1  1085.33
# 3                   NaN        NaN                  54        31    56.21
# 4                   NaN        NaN                  33        44    30.62
#
#    TIME  DAY
# 0   7.0    3
# 1  22.5    4
# 2   5.0    2
# 3  18.0    1
# 4   2.0    2

# %%
data[0][:,0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-429-b465e6931ae6> in <module>()
# ----> 1 data[0][:,0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
#label incoder  string to hash
from sklearn.preprocessing import LabelEncoder

fd=fd.apply(LabelEncoder().fit_transform)
f_ord=f_ord.apply(LabelEncoder().fit_transform)
f_vip=f_vip.apply(LabelEncoder().fit_transform)

# %%
fd.head()
# Out:
#    VEHICLE_TYPE  TOTAL_LUGGAGE_WEIGHT  WAIT_TIME  TRAFFIC_STUCK_TIME  \
# 0             2                  6005       5995                   8
# 1             5                     6          9                  66
# 2             6                    17          6                  53
# 3             3                  8787       8777                  54
# 4             2                  8788       8778                  33
#
#    DISTANCE   FARE  TIME  DAY  CITY
# 0        34   1124    14    3     5
# 1        34  12960    45    4     1
# 2         1  13180    10    2     2
# 3        31   3230    36    1     1
# 4        44    994     4    2     3

# %% [markdown]
# # All  calculations for f_ord......

# %%
x=f_ord.drop('FARE',axis=1)
y=f_ord['FARE']

from sklearn.cross_validation import train_test_split

x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.40,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
lin=LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred=lin.predict(x_test)

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.38685208111385994

# %%
plt.scatter(y_test,pred)

# %%
lin.coef_
# Out:
# array([ -1.29561238e+02,   4.18197627e-01,   1.51822181e+01,
#         -1.63668970e-01,   4.23957713e+00,  -5.05088534e+02])

# %%
lin.intercept_
# Out:
# 4069.4221237714473

# %%
sns.distplot(y_test-pred)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
pred=knn.predict(x_test)

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.23772775525562662

# %%
plt.scatter(y_test,pred)

# %%
sns.distplot(y_test-pred)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree=DecisionTreeRegressor()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
pred=dtree.predict(x_test)

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.79157669570112499

# %%
sns.distplot(y_test-pred)

# %%
plt.scatter(y_test,pred)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
r_forest=RandomForestRegressor()

# %%
r_forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
pred=r_forest.predict(x_test)

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.87447054764586729

# %%
sns.distplot(y_test-pred)

# %%
plt.scatter(y_test,pred)

# %% [markdown]
# # for f_vip

# %%
x=f_vip.drop('FARE',axis=1)
y=f_vip['FARE']

from sklearn.cross_validation import train_test_split

x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.40,random_state=101)

# %%
tree=DecisionTreeRegressor()

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
pred=tree.predict(x_test)

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.83665894723568091

# %%
sns.distplot(y_test-pred)

# %%
plt.scatter(y_test,pred)

# %%
#random Forest

# %%
ran_f=RandomForestRegressor()

# %%
ran_f.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
pred=ran_f.predict(x_test)

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.90737597220254851

# %%
plt.scatter(y_test,pred)

# %%
sns.distplot(y_test-pred)

# %% [markdown]
# # For Fd ..................................

# %%
from sklearn.cross_validation import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=102)

# %%
from sklearn.linear_model import LinearRegression

# %%
lir=LinearRegression()

# %%
lir.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Out:
# array([ 2402.42230518,  8032.036026  ,  5854.51815239, ...,  4191.60349406,
#         7552.66364135,  6974.11193687])

# %%
lir.coef_
# Out:
# array([  3.93519399e+02,  -4.52226821e-01,   1.63372942e-01,
#          6.24737862e+00,   5.93702116e+01,  -7.23532495e+00,
#          3.00724795e+01,  -5.70162909e+02])

# %%
lir.intercept_
# Out:
# 5946.1085812004931

# %%
new_d=pd.DataFrame(data=lir.coef_,index=x_train.columns,columns=['Coff'])

# %%
new_d
# Out:
#                             Coff
# VEHICLE_TYPE          393.519399
# TOTAL_LUGGAGE_WEIGHT   -0.452227
# WAIT_TIME               0.163373
# TRAFFIC_STUCK_TIME      6.247379
# DISTANCE               59.370212
# TIME                   -7.235325
# DAY                    30.072479
# CITY                 -570.162909

# %%
pred=lir.predict(x_test)

# %%
pred
# Out:
# array([ 2402.42230518,  8032.036026  ,  5854.51815239, ...,  4191.60349406,
#         7552.66364135,  6974.11193687])

# %%
plt.scatter(pred,y_test)

# %%
sns.distplot(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-231-5509fa2b9ef5> in <module>()
# ----> 1 sns.distplot(y_test,pred)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     212         hist_color = hist_kws.pop("color", color)
#     213         ax.hist(a, bins, orientation=orientation,
# --> 214                 color=hist_color, **hist_kws)
#     215         if hist_color != color:
#     216             hist_kws["color"] = hist_color
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6205             # this will automatically overwrite bins,
#    6206             # so that each histogram uses the same bins
# -> 6207             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6208             m = m.astype(float)  # causes problems later if it's an int
#    6209             if mlast is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in histogram(a, bins, range, normed, weights, density)
#     786         if np.any(bins[:-1] > bins[1:]):
#     787             raise ValueError(
# --> 788                 'bins must increase monotonically.')
#     789
#     790         # Initialize empty histogram
#
# ValueError: bins must increase monotonically.

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.37002782853638294

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,pred)
# Out:
# 2593.989133578249

# %%
metrics.mean_squared_error(y_test,pred)
# Out:
# 9938902.5873043258

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
pre_knn=knn.predict(x_test)

# %%
plt.scatter(pre_knn,y_test)

# %%
sns.distplot(y_test-pre_knn)

# %%
metrics.mean_absolute_error(y_test,pre_knn)
# Out:
# 2234.2345666666665

# %%
metrics.mean_squared_error(y_test,pre_knn)
# Out:
# 9012430.3031399995

# %% [markdown]
# # score and acc.

# %%
metrics.r2_score(y_test,pre_knn)
# Out:
# 0.42875179242766792

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
ds=DecisionTreeRegressor()

# %%
ds.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
pre_ds=ds.predict(x_test)

# %%
plt.scatter(pre_ds,y_test)

# %%
sns.distplot(y_test-pre_ds)

# %%
metrics.mean_absolute_error(y_test,pre_ds)
# Out:
# 397.01166666666666

# %%
mse=metrics.mean_squared_error(y_test,pre_ds)

# %%
import math

# %%
math.sqrt(mse)
# Out:
# 1486.1049874307894

# %% [markdown]
# # for score and accuracy

# %%
metrics.r2_score(y_test,pre_ds)
# Out:
# 0.86001486688872086

# %%
#Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
pred_rfr=rfr.predict(x_test)

# %%
plt.scatter(y_test,pred_rfr)

# %%
sns.distplot(y_test-pred_rfr)

# %%
metrics.r2_score(y_test,pred_rfr)
# Out:
# 0.92003885407598374
